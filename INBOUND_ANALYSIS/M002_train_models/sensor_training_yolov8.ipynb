# %% [markdown]
# ## 1. DOWNLOAD DATASET

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="SX0f6TLX5YB5nSQggeJm")
project = rf.workspace("boxesonconveyor").project("sensor_keypoint-arspc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to sensor_keypoint-1 in yolov8:: 100%|██████████| 80/80 [00:00<00:00, 1066.34it/s]

# %%
import shutil

shutil.move('sensor_keypoint-1/train', 'sensor_keypoint-1/sensor_keypoint-1/train')
shutil.move('sensor_keypoint-1/test', 'sensor_keypoint-1/sensor_keypoint-1/test')
shutil.move('sensor_keypoint-1/valid', 'sensor_keypoint-1/sensor_keypoint-1/valid')
# Out:
# 'sensor_keypoint-1/sensor_keypoint-1/valid'

# %% [markdown]
# ## 2. TRAIN MODEL

# %%
# !yolo task=pose mode=train model=yolov8l-pose.pt data=d:/Tungpv/outbound_analysis/sensor_keypoint-1/data.yaml epochs=100 imgsz=640 batch=4 device=0
# Out:
# New https://pypi.org/project/ultralytics/8.3.201 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.199  Python-3.12.10 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...
